# %% [markdown]
# # contact application
# ##### IT IS A APPLICATION WHICH WORKS ON CRUD OPERATIONS
# #### FEATURES OF APPLICATION
# * CREATING A CONTACT
# * SEARCH CONTACT
# * EDIT THE CONTACT
# * DELETE THE CONTACT
